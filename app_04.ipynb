# %% [markdown]
# # 5. 판다스

# %% [markdown]
# ## 판다스(Pandas) 시작하기

# %% [markdown]
# ## ① 판다스 모듈 설치하기
#
# ## pip install pandas

# %% [markdown]
# ## ② 판다스 모듈 불러오기

# %%
import pandas as pd

data = {
            'Name':['홍길동','이순신','강감찬'],    
            'Age': [23, 45,35]
       }

data
# Out:
# {'Name': ['홍길동', '이순신', '강감찬'], 'Age': [23, 45, 35]}

# %% [markdown]
# ## ③ 데이터프레임 생성하기

# %%
import pandas as pd

data = {
            'Name':['홍길동','이순신','강감찬'],    
            'Age': [23, 45,35]
       }

df = pd.DataFrame(data)  # 데이터프레임 만들기

df
# Out:
#   Name  Age
# 0  홍길동   23
# 1  이순신   45
# 2  강감찬   35

# %% [markdown]
# ## ④ 인덱스 추가하기

# %%
import pandas as pd

data = {
            'Name':['홍길동','이순신','강감찬'],    
            'Age': [23, 45,35]
       }

df = pd.DataFrame(data)		# 데이터프레임 만들기
df.index=['A', 'B', 'C']	# 인덱스 추가

df
# Out:
#   Name  Age
# A  홍길동   23
# B  이순신   45
# C  강감찬   35

# %% [markdown]
# ## ⑤ columns 추가하기

# %%
import pandas as pd

data = {
    		'Name':['홍길동','이순신','강감찬'],    
            'Age': [23, 45,35]
       }

df = pd.DataFrame(data)			# 데이터프레임 만들기
df.index=['A', 'B', 'C']		# 인덱스 추가
df.columns=['이름', '나이']		# 컬럼 추가

df
# Out:
#     이름  나이
# A  홍길동  23
# B  이순신  45
# C  강감찬  35

# %% [markdown]
# ## ⑥ 원하는 항목 뽑아오기

# %%
import pandas as pd
data = {
            'Name':['홍길동','이순신','강감찬'],
            'Age': [23, 45,35]
       }

df = pd.DataFrame(data, index=['A','B','C'])
df.columns=['이름','나이']

df
# Out:
#     이름  나이
# A  홍길동  23
# B  이순신  45
# C  강감찬  35

# %%
df.loc['B']
# Out:
# 이름    이순신
# 나이     45
# Name: B, dtype: object

# %% [markdown]
# ## 판다스(Pandas) 데이터프레임으로 차트 그리기

# %% [markdown]
# ## ① 판다스 데이터프레임 출력하기

# %%
import pandas as pd

data = {
            '이름':['김철수', '이영희', '김민수'],    
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)

df
# Out:
#     이름  국어  영어  수학
# 0  김철수  90  99  75
# 1  이영희  70  77  85
# 2  김민수  80  88  90

# %% [markdown]
# ## ② 판다스 인덱스 추가하기

# %%
import pandas as pd

data = {
            '이름':['김철수', '이영희', '김민수'],    
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')

df
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90

# %% [markdown]
# ## ③ 꺽은선 그래프 그리기 1

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# ③ 꺽은선 그래프 그리기 - 1

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
print(df)

fig, ax = plt.subplots()
ax.plot(df['이름'], df['국어'], color='blue', label='국어')
ax.plot(df['이름'], df['영어'], color='#FE7D27', label='영어')
ax.plot(df['이름'], df['수학'], color='green', label='수학')
ax.legend(loc='upper right')
ax.tick_params(rotation=0)
plt.title('성적 그래프')
plt.show()
# Out:
#     이름  국어  영어  수학
# 0  김철수  90  99  75
# 1  이영희  70  77  85
# 2  김민수  80  88  90

# %% [markdown]
# ## ③ 꺽은선 그래프 그리기 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic' 

data = {
            '이름':['김철수', '이영희', '김민수'],    
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')
print(df)

name = df.index.values

fig, ax = plt.subplots()
ax.plot(name, df['국어'], color='blue', label='국어')
ax.plot(name, df['영어'], color='#FE7D27', label='영어')
ax.plot(name, df['수학'], color='green', label='수학')
ax.legend(loc='upper right')
plt.title('성적 그래프')
plt.show()
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90

# %% [markdown]
# ## ④ 막대 그래프 그리기 1

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
# matplotlib.rcParams['axes.unicode_minus'] = False

# ④ 막대 그래프 그리기

data = {
            '이름': ['김철수', '이영희', '김민수'],
            '국어': [90, 70, 80],
            '영어': [99, 77, 88],
            '수학': [75, 85, 90]
       }

df = pd.DataFrame(data)
# print(df)
# print(df.shape)         # (3, 4)
# print(df.shape[0])      # 3

N = df.shape[0]         # 3
index = np.arange(N)    # [0 1 2]

fig, ax = plt.subplots()

w = 0.25
ax.bar(df.index - w, df['국어'], color='blue', label='국어', width=0.25)
ax.bar(df.index, df['영어'], color='#FE7D27', label='영어', width=0.25)
ax.bar(df.index + w, df['수학'], color='green', label='수학', width=0.25)

ax.set_xticks(index, df['이름'])
ax.tick_params(rotation=0)
ax.legend(loc='upper right', ncol=3)

plt.title('성적 그래프')
plt.show()

# %% [markdown]
# ## ④ 막대 그래프 그리기 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# 음수 기호 올바르게 나오도록 설정
# 유니코드 음수 기호('−')는 한글 폰트에서 제대로 표시되지 않을 수 있다.
# Matplotlib은 음수를 표시할 때 유니코드 음수 기호 대신 일반 ASCII 음수 기호('-')를 사용하여 해결
matplotlib.rcParams['axes.unicode_minus'] = False

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')
print(df)

N = df.shape[0]         # 3
index = np.arange(N)    # [0 1 2]
name = df.index.values  # ['김철수' '이영희' '김민수']

fig, ax = plt.subplots()

w = 0.25

ax.bar(index - w, df['국어'], color='blue', label='국어', width=0.25)
ax.bar(index, df['영어'], color='red', label='영어', width=0.25)
ax.bar(index + w, df['수학'], color='green', label='수학', width=0.25)

ax.set_xticks(index, name)
ax.tick_params(axis='x', rotation=40)
ax.tick_params(axis='y', rotation=20)
ax.legend(loc='upper right', ncol=3)

plt.show()
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90

# %% [markdown]
# ## ⑤ 원 그래프 그리기 1

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# ⑤ 원 그래프 그리기

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')
# print(df)
# print(df['국어'])
# print(df['국어'].iloc[0])     # 국어 행의 0번째 (김철수의 점수) 90

fig, ax = plt.subplots()

values = [df['국어'].iloc[0], df['국어'].iloc[1], df['국어'].iloc[2]]     # [np.int64(90), np.int64(70), np.int64(80)]
labels = [df.index[0], df.index[1], df.index[2]]                          # ['김철수', '이영희', '김민수']
explode = [0.02] * 3
colors = ['#ffadad', '#ffd6a5', '#a0c4ff']

ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode, colors=colors)
# wedgeprops = {'width': 0.6, 'edgecolor':'white', 'linewidth':5}
# ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode, colors=colors, wedgeprops=wedgeprops)

ax.legend(loc=(1.0, 0.3), title='국어 성적')
plt.title('성적 그래프')
plt.show()

# %% [markdown]
# ## ⑤ 원 그래프 그리기 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# ⑤ 원 그래프 그리기

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')
# print(df)
# print(df['국어'])
# print(df['국어'].iloc[0])     # 국어 행의 0번째 (김철수의 점수) 90

fig, ax = plt.subplots()

values = df['국어'].values    # [90 70 80]
labels = df.index.values      # ['김철수' '이영희' '김민수']
explode = [0.02] * 3
colors = ['#ffadad', '#ffd6a5', '#a0c4ff']

ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode, colors=colors)
# wedgeprops = {'width': 0.6, 'edgecolor':'white', 'linewidth':5}
# ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, explode=explode, colors=colors, wedgeprops=wedgeprops)

ax.legend(loc=(1.0, 0.3), title='국어 성적')
plt.title('성적 그래프')
plt.show()

# %% [markdown]
# ## ⑥ 과목별 원 그래프 그리기 1

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')

print(df)

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

labels = [df.index[0], df.index[1], df.index[2]]

values1 = [df['국어'].iloc[0], df['국어'].iloc[1], df['국어'].iloc[2]]
values2 = [df['영어'].iloc[0], df['영어'].iloc[1], df['영어'].iloc[2]]
values3 = [df['수학'].iloc[0], df['수학'].iloc[1], df['수학'].iloc[2]]

axes[0].pie(values1, labels=labels, autopct='%1.1f%%', startangle=90)
axes[0].set_title('국어 점수 비율')

axes[1].pie(values2, labels=labels, autopct='%1.1f%%', startangle=90)
axes[1].set_title('영어 점수 비율')

axes[2].pie(values3, labels=labels, autopct='%1.1f%%', startangle=90)
axes[2].set_title('수학 점수 비율')

plt.suptitle('성적 그래프')
plt.show()
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90

# %% [markdown]
# ## ⑥ 과목별 원 그래프 그리기 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# ⑥ 과목별 원 그래프 그리기

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')

print(df)

values1 = df['국어'].values
values2 = df['영어'].values
values3 = df['수학'].values
labels = df.index.values

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].pie(values1, labels=labels, autopct='%1.1f%%', startangle=90)
axes[0].set_title('국어점수 비율')

axes[1].pie(values2, labels=labels, autopct='%1.1f%%', startangle=90)
axes[1].set_title('영어점수 비율')

axes[2].pie(values3, labels=labels, autopct='%1.1f%%', startangle=90)
axes[2].set_title('수학점수 비율')

plt.suptitle('성적 그래프')
plt.show()
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90

# %% [markdown]
# ## ⑦ 과목별 막대그래프 그리기 1

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
# ⑦ 과목별 막대그래프 그리기
data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]}
df = pd.DataFrame(data)
df = df.set_index('이름')


fig, axes = plt.subplots(1, 3, figsize=(18, 6))

names = [df.index[0], df.index[1], df.index[2]]
values1 = [df['국어'].iloc[0], df['국어'].iloc[1], df['국어'].iloc[2]]
values2 = [df['영어'].iloc[0], df['영어'].iloc[1], df['영어'].iloc[2]]
values3 = [df['수학'].iloc[0], df['수학'].iloc[1], df['수학'].iloc[2]]

axes[0].bar(names, values1, width=0.6)
axes[0].set_xlabel('이름')
axes[0].set_title('국어 점수')

axes[1].bar(names, values2, width=0.6)
axes[1].set_xlabel('이름')
axes[1].set_title('영어 점수')

axes[2].bar(names, values3, width=0.6)
axes[2].set_xlabel('이름')
axes[2].set_title('수학 점수')

plt.suptitle('성적 그래프')
plt.show()

# %% [markdown]
# ## ⑦ 과목별 막대그래프 그리기 2

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

data = {
            '이름':['김철수', '이영희', '김민수'],
            '국어':[90, 70, 80],
            '영어':[99, 77, 88],
            '수학':[75, 85, 90]
       }

df = pd.DataFrame(data)
df = df.set_index('이름')
print(df)

values1 = df['국어'].values
values2 = df['영어'].values
values3 = df['수학'].values
names = df.index.values

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].bar(names, values1, width=0.6)
axes[0].set_xlabel('이름')
axes[0].set_title('국어 점수')

axes[1].bar(names, values2, width=0.6)
axes[1].set_xlabel('이름')
axes[1].set_title('영어 점수')

axes[2].bar(names, values3, width=0.6)
axes[2].set_xlabel('이름')
axes[2].set_title('수학 점수')

plt.suptitle('성적 그래프')
plt.show()
# Out:
#      국어  영어  수학
# 이름
# 김철수  90  99  75
# 이영희  70  77  85
# 김민수  80  88  90
