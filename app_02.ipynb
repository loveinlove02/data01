# %% [markdown]
# # 맵플로우립(Matplotlib)기본 사용법

# %% [markdown]
# ## ① 한글 폰트 설정 - ‘matplotlib.rcParams['font.family'] = 'Malgun Gothic' ’

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## ② 선 그래프를 그리는 함수 - ‘ax.plot’

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# 모든 그래프 구성요소(축, 그래픽, 텍스트, 레이블 등)를 포함하는 최상위 객체 fig 생성.
# (그래프를 그리기 전에 액자와 같은 모양을 Figure라고 하겠습니다.)
# 눈금과 레이블이 있는 테두리박스(그래프) 생성. 서브플롯입니다.
fig, ax = plt.subplots()

x = [1, 2, 3, 4, 5]       
y = [1, 4, 9, 16, 25]

ax.plot(x, y)               # 리스트 x, y를 넣어서 그래프 그리기. 리스트 x는 x축의 값, 리스트 y는 y축의 값.
ax.set_xlabel('x축 이름')   # x축 레이블 설정
ax.set_ylabel('y축 이름')   # y축 레이블 설정
plt.grid(True)              # 격자(grid) 설정
plt.title('선 그래프')      # 제목 설정
plt.show()                  # 그래프를 화면에 나타낸다.

# %% [markdown]
# ## ③ 산점도를 그리는 함수 - ‘ax.scatter’

# %% [markdown]
# ## 두 변화량 x,y의 순서쌍 (x,y)를 좌표평면 위에 점으로 나타낸 그래프
# ### 산점도를 보면 두 변량 사이의 관계를 쉽게 파악할 수 있습니다.
# ### . x의 값이 증가함에 따라 y의 값도 증가하는 경향이 있을때, 두 변량 x,y에 양의 상관관계가 있다고 합니다.
# ### . x의 값이 감소함에 따라 y의 값도 감소하는 경향이 있을때, 두 변량 x,y에 음의 상관관계가 있다고 합니다.
# ### . 산점도의 점들이 한 직선위에 모여있지 않고 흩어져 있거나, x 또는 y축에 평행하게 분포하는 경우는 상관관계가 없습니다.

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

ax.scatter(x, y)
ax.set_xlabel('x축 이름')
ax.set_ylabel('y축 이름')
plt.grid(True)
plt.title('산전도 그래프')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

matplotlib.rcParams['font.family'] = 'Malgun Gothic' 
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['axes.unicode_minus'] = False

df = pd.DataFrame(
    {
        '이름': ['홍길동', '김철수', '이영희' , '김민지', '조윤정' ,'이지영', '박민정', '윤수정'],
        '반': ['1반','2반','1반','3반','2반', '2반', '1반', '3반'],
        '국어': [95, 98, 98, 85, 65, 89, 65, 85],
        '영어': [87, 25, 96, 89, 92, 25, 85, 96],
        '수학': [85, 98, 20, 85, 89, 37, 26, 99],
        '과학': [98, 50, 88, 85, 95, 32, 19, 98], 
        '특기': ['코딩', '피아노', '미술', '코딩', '코딩', '피아노', '미술', '코딩']
    }, 
    index=['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번']
)

df['학년'] = [3, 3, 2, 1, 1, 1, 2, 3]

plt.scatter(df['영어'], df['수학'])
plt.xlabel('영어')
plt.ylabel('수학')
plt.show()

# %% [markdown]
# ## ④ 가로 막대 그래프를 그리는 함수 - ‘ax.barh’

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 6]

ax.barh(categories, values)    # 첫 번째 인자는 Y축. 두 번째 인자는 X축.
ax.set_xlabel('값')
ax.set_ylabel('카테고리')
plt.grid(True)
plt.title('가로막대 그래프')
plt.show()

# %% [markdown]
# ## ⑤ 세로 막대 그래프를 그리는 함수 - ‘ax.bar’

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 6]

ax.bar(categories, values)  # 첫 번째 인자는 X축. 두 번째 인자는 Y축.
ax.set_xlabel('카테고리')
ax.set_ylabel('값')
plt.grid(True)
plt.title('세로막대 그래프')
plt.show()

# %% [markdown]
# ## ⑥ 그래프의 제목 설정 - ‘plt.title’

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 3, 8, 6]

ax.bar(categories, values)  # 첫 번째 인자는 X축. 두 번째 인자는 Y축.
ax.set_xlabel('카테고리')
ax.set_ylabel('값')

# plt.title('그래프 제목')              # 기본
# plt.title('그래프 제목', loc='left')	# 제목을 넣을 위치 (left, center, right)
# plt.title('그래프 제목', pad=20)	    # pad : 제목과 그래프의 간격 (숫자)

# fontdict : 제목의 글꼴. 딕셔너리로 설정
#   fontsize - 제목 크기 (숫자)
#   fontweight - nomal, bold, heavy, light
#   color - 제목 색깔
plt.title('그래프 제목', fontdict={'fontfamily': 'NanumGothic', 'fontsize': 18, 'fontweight':'bold', 'color':'blue'})

plt.grid(True)
plt.show()

# %% [markdown]
# ## 폰트

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
# mpl.rcParams['axes.unicode_minus'] = False

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
f = [f.name for f in fm.fontManager.ttflist]

for f in fm.fontManager.ttflist:
    if 'Nanum' in f.name:
        print(f.name, f.fname)
# Out:
# NanumMyeongjo C:\Windows\Fonts\NanumMyeongjo.ttf
# NanumMyeongjo C:\Windows\Fonts\NanumMyeongjoExtraBold.ttf
# NanumMyeongjo C:\Windows\Fonts\NanumMyeongjoBold.ttf
# NanumGothic C:\Windows\Fonts\NanumGothicBold.ttf
# NanumGothic C:\Windows\Fonts\NanumGothic.ttf
# NanumGothic C:\Windows\Fonts\NanumGothicLight.ttf
# NanumGothic C:\Windows\Fonts\NanumGothicExtraBold.ttf

# %% [markdown]
# ## ⑧ x축 이름 설정 - 'ax.set_xlabel'

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

ax.plot(x, y)

# labelpad: 레이블 여백 (숫자)
# loc: 레이블 위치.
#   ax.set_xlabel(loc='center') - 'left', 'center', 'right'
#   ax.set_ylabel(loc='top')    - 'bottom', 'center', 'top’
# color: 레이블 색깔.
ax.set_xlabel('x축 이름', labelpad=10, loc='center', color='blue')

plt.title('그래프 제목', fontdict={'fontfamily': 'NanumGothic', 'fontsize': 18, 'fontweight':'bold', 'color':'blue'})

plt.show()

# %% [markdown]
# ## ⑨ 범례 설정 - 'ax.legend'

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

ax.plot(x, y, label='범례 설정')
ax.set_xlabel('x축 이름', labelpad=10, loc='center', color='blue')

# loc: 위치.
#      best, upper right, upper left, upper center
#            lower right, lower left, lower center
#            center right, center left, center
# fontsize: 글씨 크기 (숫자)
# shadow  : 그림자 (True, False)
# fontsize: 글씨 크기 (숫자)
# shadow  : 그림자 (True, False)
ax.legend(loc='upper right', fontsize=12, shadow=True)

# x축, y축 범위는 0~1 값의 범위
# x축 기준으로 0.5 y축 기준으로 0.5에 그린다. 가운데에 그려진다.
# ax.legend(loc=(0.5, 0.5))

plt.title('그래프 제목', fontdict={'fontfamily': 'NanumGothic', 'fontsize': 18, 'fontweight':'bold', 'color':'blue'})
plt.show()

# %% [markdown]
# ## ⑩ 격자 설정 - 'plt.grid()'

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots()

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

ax.plot(x, y, label='범례 설정')

ax.set_xlabel('x축 이름', labelpad=10, loc='center', color='blue')
ax.legend(loc='upper right', fontsize=12, shadow=True)

# True로 설정하면 x, y 축 둘 다 표시
# plt.grid(True, axis='y') 가로 방향
# plt.grid(True, axis='x') 세 로 방향
# 격자(그리드) y는 가로 방향. 색깔 회색, 투명도 0.2, 선 스타일 실선, 선 두께 1
plt.grid(True, axis='y', color='gray', alpha=0.2, linestyle='-', linewidth=1)

plt.title('그래프 제목', fontdict={'fontfamily': 'NanumGothic', 'fontsize': 18, 'fontweight':'bold', 'color':'blue'})
plt.show()
